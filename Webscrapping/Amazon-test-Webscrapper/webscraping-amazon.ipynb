# %% [markdown]
# ### PLAYSTATION 5 WEBSCRAPER

# %%
from bs4 import BeautifulSoup
from pip._vendor import requests
import pandas as pd
from IPython.display import display, HTML



def title(soup):
    try:
        title = soup.find("span", attrs={"id": "productTitle"})
        title_name = title.get_text(strip=True) if title else ""
    except AttributeError:
        title_name = ""
    return title_name



def prices(soup):
    try:
        price = soup.find("span", attrs={"class": "a-price-whole"})
        price_value = price.get_text(strip=True) if price else ""
    except AttributeError:
        price_value = ""
    return price_value



def ratings(soup):
    try:
        rating = soup.find("span", attrs={"class": "a-icon-alt"})
        rating_text = rating.get_text(strip=True) if rating else ""
    except AttributeError:
        rating_text = ""
    return rating_text



def reviews(soup):
    try:
        review = soup.find("span", attrs={"id": "acrCustomerReviewText"})
        review_text = review.get_text(strip=True) if review else ""
    except AttributeError:
        review_text = ""
    return review_text




URL = "https://www.amazon.co.uk/s?k=playstation+5&crid=1DZW6085PFENM&sprefix=playst%2Caps%2C76&ref=nb_sb_ss_ts-doa-p_2_6"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"
}

response = requests.get(URL, headers=HEADERS)
soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all("a", class_="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal")


product_list = []

for link in links:
    product_path = link.get("href")
    if product_path.startswith("/"):
        product_url = "https://www.amazon.co.uk" + product_path
    else:
        product_url = product_path

    product_response = requests.get(product_url, headers=HEADERS)
    product_soup = BeautifulSoup(product_response.text, "html.parser")

    product_data = {
        "Title": title(product_soup),
        "Price": prices(product_soup),
        "Rating": ratings(product_soup),
        "Reviews": reviews(product_soup)
    }

    product_list.append(product_data)


df = pd.DataFrame(product_list)


display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Title</th>
#       <th>Price</th>
#       <th>Rating</th>
#       <th>Reviews</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PlayStation 5</td>
#       <td>479.</td>
#       <td>4.4 out of 5 stars</td>
#       <td>80 ratings</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>PlayStation 5 Digital Edition</td>
#       <td>389.</td>
#       <td>4.2 out of 5 stars</td>
#       <td>39 ratings</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>PlayStation 5 Standard Console</td>
#       <td>505.</td>
#       <td>4.8 out of 5 stars</td>
#       <td>20,646 ratings</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Maecker vr Headstrap Compatible with Quest 3 Head Strap for Quest 3 Accessories Comfortable Stable Elite Strap</td>
#       <td>30.</td>
#       <td>4.6 out of 5 stars</td>
#       <td>185 ratings</td>
# ...

# %%
from bs4 import BeautifulSoup
from pip._vendor import requests
import pandas as pd
from IPython.display import display, HTML



def title(soup):
    try:
        title = soup.find("span", attrs={"id": "productTitle"})
        title_name = title.get_text(strip=True) if title else ""
    except AttributeError:
        title_name = ""
    return title_name



def prices(soup):
    try:
        price = soup.find("span", attrs={"class": "a-price-whole"})
        price_value = price.get_text(strip=True) if price else ""
    except AttributeError:
        price_value = ""
    return price_value



def ratings(soup):
    try:
        rating = soup.find("span", attrs={"class": "a-icon-alt"})
        rating_text = rating.get_text(strip=True) if rating else ""
    except AttributeError:
        rating_text = ""
    return rating_text



def reviews(soup):
    try:
        review = soup.find("span", attrs={"id": "acrCustomerReviewText"})
        review_text = review.get_text(strip=True) if review else ""
    except AttributeError:
        review_text = ""
    return review_text

# %% [markdown]
# Importing Libraries:
#
# from bs4 import BeautifulSoup: This line imports the BeautifulSoup class from the bs4 module. BeautifulSoup is a popular library for parsing HTML and XML documents.
# from pip._vendor import requests: This line imports the requests module, which is used for sending HTTP requests to web pages.
# import pandas as pd: This line imports the Pandas library with the alias pd. Pandas is used for data manipulation and analysis.
# from IPython.display import display, HTML: This line imports functions display and HTML from the IPython.display module, which is often used for displaying HTML content in IPython/Jupyter notebooks.
# Functions:
#
# The code defines several functions, each of which is designed to extract specific information from a BeautifulSoup object (presumably representing an Amazon product page).
#
# title(soup): This function attempts to find and return the product title from the BeautifulSoup object soup. It looks for an HTML element with the attribute id="productTitle" and extracts its text content.
#
# prices(soup): This function tries to find and return the product price from soup. It looks for an HTML element with the class a-price-whole and extracts its text content.
#
# ratings(soup): This function attempts to find and return the product rating from soup. It looks for an HTML element with the class a-icon-alt and extracts its text content.
#
# reviews(soup): This function tries to find and return the number of customer reviews from soup. It looks for an HTML element with the attribute id="acrCustomerReviewText" and extracts its text content.
#
# Error Handling:
#
# Each of the functions includes a try and except block to handle potential errors (e.g., if the specified HTML elements are not found on the page). If an error occurs, the function sets the corresponding result to an empty string.

# %%
URL = "https://www.amazon.co.uk/s?k=playstation+5&crid=1DZW6085PFENM&sprefix=playst%2Caps%2C76&ref=nb_sb_ss_ts-doa-p_2_6"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36"
}

response = requests.get(URL, headers=HEADERS)
soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all("a", class_="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal")

links
# Out:
# []

# %% [markdown]
# Define a Target URL:
#
# URL = "https://www.amazon.co.uk/s?k=playstation+5&crid=1DZW6085PFENM&sprefix=playst%2Caps%2C76&ref=nb_sb_ss_ts-doa-p_2_6": This line defines a variable URL containing the URL of an Amazon search page for the query "playstation 5" in the Amazon UK store.
# Define User-Agent Headers:
#
# HEADERS: This dictionary contains User-Agent headers that mimic a web browser's User-Agent string. It's used to make the HTTP request to the URL appear as if it's coming from a web browser, which can help in avoiding server-side restrictions or bot detection mechanisms. These headers specify the user agent as a Windows 10-based system using Chrome.
# Send an HTTP GET Request to the URL:
#
# response = requests.get(URL, headers=HEADERS): This line sends an HTTP GET request to the specified URL using the requests.get() function from the requests module. It includes the User-Agent headers from HEADERS. The response from the server is stored in the response variable.
# Parse the HTML Response:
#
# soup = BeautifulSoup(response.text, "html.parser"): This line creates a BeautifulSoup object named soup by parsing the HTML content of the HTTP response. BeautifulSoup is a library used for parsing HTML and XML documents. It allows you to navigate and extract information from HTML documents more easily.
# Find All Links Matching a Specific Criteria:
#
# links = soup.find_all("a", class_="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"): This line uses the find_all() method of the BeautifulSoup object to search for all HTML <a> elements (links) that have the specified combination of classes. These classes are used by Amazon's website to style links that are part of search results. The result is a list of matching link elements, which can be further processed to extract information or follow the links to other pages.

# %%
product_list = []

for link in links:
    product_path = link.get("href")
    if product_path.startswith("/"):
        product_url = "https://www.amazon.co.uk" + product_path
    else:
        product_url = product_path

    product_response = requests.get(product_url, headers=HEADERS)
    product_soup = BeautifulSoup(product_response.text, "html.parser")

    product_data = {
        "Title": title(product_soup),
        "Price": prices(product_soup),
        "Rating": ratings(product_soup),
        "Reviews": reviews(product_soup)
    }

    product_list.append(product_data)


df = pd.DataFrame(product_list)


display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# Initialize an Empty List for Product Data:
#
# product_list = []: This line creates an empty list called product_list to store information about the products found on the Amazon search page.
# Loop Through Links:
#
# for link in links:: This is a loop that iterates through each link (HTML <a> element) extracted from the previous step. These links are the product listings on the Amazon search page.
# Extract Product URL:
#
# product_path = link.get("href"): This line extracts the href attribute (URL) from the link element.
# if product_path.startswith("/"):: It checks if the product_path starts with a forward slash /. If it does, it means the URL is relative, so it appends the base URL ("https://www.amazon.co.uk") to create the complete product URL.
# else:: If the product_path doesn't start with a forward slash, it's assumed to be an absolute URL, and no modification is needed.
# Send an HTTP GET Request to Each Product URL:
#
# product_response = requests.get(product_url, headers=HEADERS): This line sends an HTTP GET request to the product URL (either relative or absolute) to retrieve the product's HTML content.
# product_soup = BeautifulSoup(product_response.text, "html.parser"): It creates a BeautifulSoup object (product_soup) to parse the HTML content of the product page.
# Extract Product Information:
#
# product_data = {...}: This dictionary is created to store information about the current product. It includes "Title," "Price," "Rating," and "Reviews." The information is extracted by calling the functions title, prices, ratings, and reviews on the product_soup object, which extracts the relevant data from the product page.
# Append Product Data to the List:
#
# product_list.append(product_data): This adds the extracted product data to the product_list.
# Create a Pandas DataFrame:
#
# df = pd.DataFrame(product_list): After collecting information about multiple products in product_list, this line converts the list of dictionaries into a Pandas DataFrame. Each dictionary in the list represents a row in the DataFrame.
# Display the DataFrame as HTML:
#
# display(HTML(df.to_html())): Finally, this code displays the Pandas DataFrame in an HTML format using the display function. This is often used in environments like Jupyter Notebook or IPython to render the DataFrame as a table for easy viewing.
